# %% [markdown]
# # Adattisztítás és integráció

# %% [markdown]
# A valós adathalmazok gyakran zajosak, hiányosak, avagy éppen redundáns információt vagy duplikátum egyedeket tartalmaznak. Ezért a tudásfeltárás folyamatában az adattisztítás és adatintegrálással kezdődik.
#
# Az adattisztítás szerepe javítani az adatok minőségén azáltal, hogy kiszűri és eltávolítja az adatokban fellépő hibákat és inkonzisztenciákat.
#
# Az [adattisztítás](https://hu.wikipedia.org/wiki/Adattiszt%C3%ADtás) során:
# "
# - felmérjük a hibákat
# 	- ellenőrizzük az adatfájl szerkezeti épségét
# 	- a zajt, felesleges információt tartalmazó mezőket javítjuk
# 	- felmérjük a hiányzó értékeket és amennyiben lehet ezeket pótoljuk
# 	- felmérjük az adatközlési és adatbeviteli hibákat
# 		- megvizsgáljuk az egyes változók eloszlását
# 			- az eloszlások szélein elhelyezkedő extrém értékeket ellenőrizzük
# 			- felmérjük, hogy az eloszlások megfelelnek-e az előzetes elvárásainknak, vannak-e nem várt sűrűsödések, ritkulások egyes értéktartományokban (például durva kerekítés vagy eltérő mértékegység használata az adatszolgáltatók egy részénél)
# 		-  megvizsgáljuk, hogy a változók közötti triviális összefüggések teljesülnek-e
# -  a hibásnak tűnő adatokat felülvizsgáljuk, javítjuk
# ".

# %% [markdown]
# # Feladatok

# %% [markdown]
# 1. Az `egyetemek.txt` fájlból szűrjük ki az államokat és azon belül a városokat, melyben egyetemek találhatóak. Ha vannak duplikátumok, helytelen adatok (pl. számokat tartalmazó államnév), ezeket javítsuk. Vizsgáljuk meg az egyetemek eloszlását államok szerint. Melyik államban van a legtöbb, legkevesebb egyetem?

# %%
with open('/content/sample_data/egyetemek.txt', 'r', encoding='utf-8') as f:
    data = f.readlines()

universities = {}

for line in data:
    line = line.strip()
    if line:
        try:
            state, unis = line.split("[edit]")
            state = state.strip()
            unis = unis.strip().strip("[]")
            uni_list = unis.split(",")
            universities[state] = [uni.strip() for uni in uni_list]
        except ValueError:
            print(f"Could not process line: {line}")

for line in data:
    line = line.strip()
    if line:
        state, unis = line.split("[edit]") if "[edit]" in line else (line, "")
        state = state.strip()
        unis = unis.strip().strip("[]")
        uni_list = unis.split(",")
        universities[state] = [uni.strip() for uni in uni_list]

counts = {state: len(unis) for state, unis in universities.items()}

most_unis_state = max(counts, key=counts.get)
least_unis_state = min(counts, key=counts.get)

print("**********************************************************")
print(f"Legtöbb egyetem: {most_unis_state} ({counts[most_unis_state]} db)")
print(f"Legkevesebb egyetem: {least_unis_state} ({counts[least_unis_state]} db)")
print("**********************************************************")

# print(universities)
# Out:
# Could not process line: Auburn (Auburn University)[1]
# Could not process line: Florence (University of North Alabama)
# Could not process line: Jacksonville (Jacksonville State University)[2]
# Could not process line: Livingston (University of West Alabama)[2]
# Could not process line: Montevallo (University of Montevallo)[2]
# Could not process line: Troy (Troy University)[2]
# Could not process line: Tuscaloosa (University of Alabama, Stillman College, Shelton State)[3][4]
# Could not process line: Tuskegee (Tuskegee University)[5]
# Could not process line: Fairbanks (University of Alaska Fairbanks)[2]
# Could not process line: Flagstaff (Northern Arizona University)[6]
# Could not process line: Tempe (Arizona State University)
# Could not process line: Tucson (University of Arizona)
# Could not process line: Arkadelphia (Henderson State University, Ouachita Baptist University)[2]
# Could not process line: Conway (Central Baptist College, Hendrix College, University of Central Arkansas)[2]
# Could not process line: Fayetteville (University of Arkansas)[7]
# Could not process line: Jonesboro (Arkansas State University)[8]
# Could not process line: Magnolia (Southern Arkansas University)[2]
# Could not process line: Monticello (University of Arkansas at Monticello)[2]
# Could not process line: Russellville (Arkansas Tech University)[2]
# Could not process line: Searcy (Harding University)[5]
# Could not process line: Angwin (Pacific Union College)[2]
# Could not process line: Arcata (Humboldt State University)[5]
# Could not process line: Berkeley (University of California, Berkeley)[5]
# Could not process line: Chico (California State University, Chico)[2]
# Could not process line: Claremont (Claremont McKenna College, Pomona College, Harvey Mudd College, Scripps College, Pitzer College, Keck Graduate Institute, Claremont Graduate University)[5]
# Could not process line: Cotati (California State University, Sonoma)[2]
# Could not process line: Davis (University of California, Davis)[1]
# Could not process line: Irvine (University of California, Irvine)
# Could not process line: Isla Vista (University of California, Santa Barbara)[2]
# Could not process line: University Park, Los Angeles (University of Southern California)
# Could not process line: Merced (University of California, Merced)
# Could not process line: Orange (Chapman University)
# Could not process line: Palo Alto (Stanford University)
# Could not process line: Pomona (Cal Poly Pomona, WesternU)[9][10][11] and formerly Pomona College
# Could not process line: Davis (California, Davis)[2]
# Could not process line: Redlands (University of Redlands)
# Could not process line: Riverside (University of California, Riverside, California Baptist University, La Sierra University)
# Could not process line: Sacramento (California State University, Sacramento)
# Could not process line: University District, San Bernardino (California State University, San Bernardino, American Sports University)
# Could not process line: San Diego (University of California, San Diego, San Diego State University)
# Could not process line: San Luis Obispo (California Polytechnic State University)[2]
# Could not process line: Santa Barbara (Fielding Graduate University, Santa Barbara City College, University of California, Santa Barbara, Westmont College)[2]
# Could not process line: Santa Cruz (University of California, Santa Cruz)[2]
# Could not process line: Turlock (California State University, Stanislaus)
# Could not process line: Westwood, Los Angeles (University of California, Los Angeles)[2]
# Could not process line: Whittier (Whittier CollegeRio Hondo College)
# Could not process line: Alamosa (Adams State College)[2]
# Could not process line: Boulder (University of Colorado at Boulder)[12]
# Could not process line: Durango (Fort Lewis College)[2]
# Could not process line: Fort Collins (Colorado State University)[13]
# Could not process line: Golden (Colorado School of Mines)
# Could not process line: Grand Junction (Colorado Mesa University)
# Could not process line: Greeley (University of Northern Colorado)
# Could not process line: Gunnison (Western State College)[2]
# Could not process line: Pueblo, Colorado (Colorado State University-Pueblo)
# Could not process line: Fairfield (Fairfield University, Sacred Heart University)
# Could not process line: Middletown (Wesleyan University)
# Could not process line: New Britain (Central Connecticut State University)
# Could not process line: New Haven (Yale University, University of New Haven, Southern Connecticut State University, Albertus Magnus College, Quinnipiac University)[14]
# Could not process line: New London (Connecticut College, US Coast Guard Academy, Mitchell College)[2]
# Could not process line: Storrs (University of Connecticut)[2]
# Could not process line: Willimantic (Eastern Connecticut State University)[2]
# Could not process line: Dover (Delaware State University)[1]
# Could not process line: Newark (University of Delaware)[1]
# Could not process line: Ave Maria (Ave Maria University)
# Could not process line: Boca Raton (Florida Atlantic University)
# Could not process line: Coral Gables (University of Miami)
# Could not process line: DeLand (Stetson University)[5]
# Could not process line: Estero (Florida Gulf Coast University)
# Could not process line: Gainesville (University of Florida, Santa Fe College)
# Could not process line: Orlando (University of Central Florida)
# Could not process line: Sarasota (New College of Florida, Ringling College of Art and Design, State College of Florida, Manatee-Sarasota, University of South Florida Sarasota-Manatee)
# Could not process line: St. Augustine (Flagler College)
# Could not process line: St. Leo (St. Leo University)
# Could not process line: Tallahassee (Florida State University, Florida A&M University)
# Could not process line: Tampa (University of South Florida)
# Could not process line: Albany (Albany State University)
# Could not process line: Athens (University of Georgia)[15]
# Could not process line: Atlanta (Georgia State University, Georgia Tech, Emory)[2]
# Could not process line: Carrollton (University of West Georgia)[2]*Dahlonega (North Georgia College & State University)[2]
# Could not process line: Demorest (Piedmont College)[2]
# Could not process line: Fort Valley (Fort Valley State University)[2]
# Could not process line: Kennesaw (Kennesaw State University)
# Could not process line: Milledgeville (Georgia College & State University)[2]
# Could not process line: Mount Vernon (Brewton-Parker College)[2]
# Could not process line: Oxford (Oxford College)
# Could not process line: Rome (Berry College, Shorter University)
# Could not process line: Savannah (Armstrong Atlantic State University, Savannah State University, Savannah College of Art and Design)
# Could not process line: Statesboro (Georgia Southern University)[5]
# Could not process line: Valdosta (Valdosta State University)[2]
# Could not process line: Waleska (Reinhardt College)[2]
# Could not process line: Young Harris (Young Harris College)[2]
# Could not process line: Manoa (University of Hawaii at Manoa)[2]
# Could not process line: Moscow (University of Idaho)[2]
# Could not process line: Pocatello (Idaho State University)[2]
# Could not process line: Rexburg (BYU-Idaho)[2]
# Could not process line: Carbondale (Southern Illinois University Carbondale)[5]
# Could not process line: Champaign–Urbana (University of Illinois at Urbana–Champaign)[5]
# Could not process line: Charleston (Eastern Illinois University)[2]
# Could not process line: DeKalb (Northern Illinois University)[2]
# Could not process line: Edwardsville (Southern Illinois University Edwardsville)[2]
# Could not process line: Evanston (Northwestern University)[2]
# Could not process line: Lebanon (McKendree University)[2]
# Could not process line: Macomb (Western Illinois University)[2]
# Could not process line: Normal (Illinois State University)[2]
# Could not process line: Peoria (Bradley University)
# Could not process line: Bloomington (Indiana University Bloomington)[5]
# Could not process line: Crawfordsville (Wabash College)
# Could not process line: Greencastle (DePauw University)[5]
# Could not process line: Hanover (Hanover College)[2]
# Could not process line: Marion (Indiana Wesleyan University)[2]
# Could not process line: Muncie (Ball State University)[2]
# Could not process line: Oakland City (Oakland City University)[2]
# Could not process line: Richmond (Earlham College)[2]
# Could not process line: South Bend (Notre Dame University[2])
# Could not process line: Terre Haute (Indiana State University, Rose-Hulman Institute of Technology)[2]
# Could not process line: Upland (Taylor University)[2]
# Could not process line: Valparaiso (Valparaiso University)
# Could not process line: West Lafayette (Purdue University)[2]
# Could not process line: Ames (Iowa State University)[2]
# Could not process line: Cedar Falls (University of Northern Iowa)[2]
# Could not process line: Cedar Rapids, Iowa (Coe College )
# Could not process line: Decorah (Luther College)[5]
# Could not process line: Fayette (Upper Iowa University)[2]
# Could not process line: Grinnell (Grinnell College)[15]
# Could not process line: Iowa City (University of Iowa)[15]
# Could not process line: Lamoni (Graceland University)[2]
# Could not process line: Mount Vernon, (Cornell College)
# Could not process line: Orange City (Northwestern College)[2]
# Could not process line: Sioux Center (Dordt College)[2]
# Could not process line: Storm Lake (Buena Vista University)[2]
# Could not process line: Waverly (Wartburg College)[2]
# Could not process line: Baldwin City (Baker University)[5]
# Could not process line: Emporia (Emporia State University)[2]
# Could not process line: Hays (Fort Hays State University)[2]
# Could not process line: Lawrence (University of Kansas, Haskell Indian Nations University)[15]
# Could not process line: Manhattan (Kansas State University, Manhattan Christian College)[15]
# Could not process line: Pittsburg (Pittsburg State University)[2]
# Could not process line: Bowling Green (Western Kentucky University)[2]
# Could not process line: Columbia (Lindsey Wilson College)[2]
# Could not process line: Georgetown (Georgetown College)
# Could not process line: Highland Heights (Northern Kentucky University)
# Could not process line: Lexington (University of Kentucky, Transylvania University[5]
# Could not process line: Louisville (University of Louisville)
# Could not process line: Morehead (Morehead State University)[2]
# Could not process line: Murray (Murray State University)[5]
# Could not process line: Richmond (Eastern Kentucky University)[2]
# Could not process line: Williamsburg (University of the Cumberlands)[2]
# Could not process line: Wilmore (Asbury University, Asbury Theological Seminary)[2]
# Could not process line: Baton Rouge (Louisiana State University, Southern University)
# Could not process line: Grambling (Grambling State University)[5]
# Could not process line: Hammond (Southeastern Louisiana University)[2]
# Could not process line: Lafayette (University of Louisiana at Lafayette)
# Could not process line: Monroe (University of Louisiana at Monroe)[2]
# Could not process line: Natchitoches (Northwestern State University)[2]
# Could not process line: Ruston (Louisiana Tech University)[2]
# Could not process line: Thibodaux (Nicholls State University)[2]
# Could not process line: Augusta (University of Maine at Augusta)[2]
# Could not process line: Bar Harbor (College of the Atlantic)
# Could not process line: Brunswick (Bowdoin College)
# Could not process line: Farmington (University of Maine at Farmington)[2]
# Could not process line: Fort Kent (University of Maine at Fort Kent)
# Could not process line: Gorham (University of Southern Maine)[2]
# Could not process line: Lewiston, Maine (Bates College)
# Could not process line: Orono (University of Maine)[2]
# Could not process line: Waterville (Thomas College, Colby College)
# Could not process line: Annapolis (United States Naval Academy, St. John's College)
# Could not process line: Chestertown (Washington College)[2]
# Could not process line: College Park (University of Maryland, College Park)[16]
# Could not process line: Cumberland (Allegany College of Maryland)
# Could not process line: Emmitsburg (Mount St. Mary's University)[2]
# Could not process line: Frostburg (Frostburg State University)[5]
# Could not process line: Princess Anne (University of Maryland Eastern Shore)[5]
# Could not process line: Towson (Towson University, Goucher College)[2]
# Could not process line: Salisbury (Salisbury University)[2]
# Could not process line: Westminster (McDaniel College)
# Could not process line: Boston (Boston University, Boston College, Boston Conservatory, New England Conservatory, Brandeis University, Northeastern University, UMass Boston, Emmanuel College, Bunker Hill Community College, Roxbury Community College, Suffolk University, Simmons College, among many others)
# Could not process line: Bridgewater (Bridgewater State College)[2]
# Could not process line: Cambridge (Harvard University, Massachusetts Institute of Technology)(Lesley University, Cambridge College, Longy School of Music)[15]
# Could not process line: Chestnut Hill (Boston College)
# Could not process line: The Colleges of Worcester Consortium:
# Could not process line: Dudley (Nichols College)
# Could not process line: North Grafton (Cummings School of Veterinary Medicine at Tufts University)
# Could not process line: Paxton (Anna Maria College)
# Could not process line: Worcester (Assumption, Becker, Clark University, Holy Cross, Mass. College of Pharmacy & Health Sciences, Quinsigamond Community College, UMass Medical School, Worcester State University, Worcester Polytechnic Institute)
# Could not process line: The Five College Region of Western Massachusetts:
# Could not process line: Amherst (Amherst College, Hampshire College, University of Massachusetts Amherst)[15]
# Could not process line: Northampton (Smith College)
# Could not process line: South Hadley (Mount Holyoke College)
# Could not process line: Fitchburg (Fitchburg State College)
# Could not process line: North Adams (Massachusetts College of Liberal Arts)
# Could not process line: Springfield (American International College), (Springfield College), and (Western New England College)
# Could not process line: Waltham (Bentley University), (Brandeis University)
# Could not process line: Williamstown (Williams College)
# Could not process line: Framingham (Framingham State University)
# Could not process line: Adrian (Adrian College, Siena Heights University)
# Could not process line: Albion (Albion College)[17]
# Could not process line: Allendale (Grand Valley State University)
# Could not process line: Alma (Alma College)
# Could not process line: Ann Arbor (University of Michigan)[1]
# Could not process line: Berrien Springs (Andrews University)[2]
# Could not process line: Big Rapids (Ferris State University)[2]
# Could not process line: East Lansing (Michigan State University)[2]
# Could not process line: Flint (Kettering University, University of Michigan-Flint)
# Could not process line: Hillsdale (Hillsdale College)
# Could not process line: Houghton (Michigan Technological University)[5]
# Could not process line: Kalamazoo (Western Michigan University, Kalamazoo College)[2]
# Could not process line: Marquette (Northern Michigan University)[2]
# Could not process line: Midland (Northwood University)
# Could not process line: Mount Pleasant (Central Michigan University)[2]
# Could not process line: Olivet (Olivet College)[2]
# Could not process line: Saginaw (Saginaw Valley State University)
# Could not process line: Sault Ste. Marie (Lake Superior State University)
# Could not process line: Spring Arbor (Spring Arbor University)[2]
# Could not process line: Ypsilanti (Eastern Michigan University)[2]
# Could not process line: Bemidji (Bemidji State University)[2]
# Could not process line: Crookston (University of Minnesota Crookston)[2]
# Could not process line: Duluth (University of Minnesota Duluth, Lake Superior College, The College of St. Scholastica, University of Wisconsin–Superior, Duluth Business University
# Could not process line: Faribault, South Central College
# Could not process line: Mankato (Minnesota State University, Mankato),[2] Bethany Lutheran College
# Could not process line: Marshall (Southwest Minnesota State University)[2]
# Could not process line: Moorhead (Minnesota State University, Moorhead, Concordia College)[18]
# Could not process line: Morris (University of Minnesota Morris)[2]
# Could not process line: Northfield (Carleton College, St. Olaf College)[5]
# Could not process line: North Mankato, South Central College
# Could not process line: St. Cloud (St. Cloud State University, The College of St. Scholastica)[2]
# Could not process line: St. Joseph (College of Saint Benedict)[2]
# Could not process line: St. Peter (Gustavus Adolphus College)[2]
# Could not process line: Winona (Winona State University, St. Mary's University of Minnesota)[19]
# Could not process line: Cleveland (Delta State University)[2]
# Could not process line: Hattiesburg (University of Southern Mississippi)[20]
# Could not process line: Itta Bena (Mississippi Valley State University)[2]
# Could not process line: Oxford (University of Mississippi)[2]
# Could not process line: Starkville (Mississippi State University)[2]
# Could not process line: Bolivar (Southwest Baptist University)[2]
# Could not process line: Cape Girardeau (Southeast Missouri State University)[2]
# Could not process line: Columbia (University of Missouri, Stephens College, Columbia College)[20]
# Could not process line: Fayette (Central Methodist University)[2]
# Could not process line: Fulton (Westminster College and William Woods University).
# Could not process line: Kirksville (Truman State University, A. T. Still University)[2]
# Could not process line: Maryville (Northwest Missouri State University)[2]
# Could not process line: Rolla (Missouri University of Science and Technology)[2]
# Could not process line: Warrensburg (University of Central Missouri)[5]
# Could not process line: Bozeman (Montana State University)[2]
# Could not process line: Dillon (University of Montana Western)[2]
# Could not process line: Missoula (University of Montana)[5]
# Could not process line: Chadron (Chadron State College)[5]
# Could not process line: Crete (Doane College)[2]
# Could not process line: Kearney (University of Nebraska at Kearney)[2]
# Could not process line: Lincoln (University of Nebraska at Lincoln)[5]
# Could not process line: Peru (Peru State College)[2]
# Could not process line: Seward (Concordia University)[2]
# Could not process line: Wayne (Wayne State College)[2]
# Could not process line: Las Vegas (University of Nevada, Las Vegas)
# Could not process line: Reno (University of Nevada, Reno)
# Could not process line: New London, New Hampshire (Colby-Sawyer College)
# Could not process line: Durham (University of New Hampshire)[2]
# Could not process line: Hanover (Dartmouth College)[5]
# Could not process line: Henniker (New England College)
# Could not process line: Keene (Keene State College)[2]
# Could not process line: Plymouth (Plymouth State University)[2]
# Could not process line: Rindge (Franklin Pierce University)
# Could not process line: Ewing (The College of New Jersey), (Rider University)
# Could not process line: Jersey City (New Jersey City University), (Saint Peter's University)
# Could not process line: Glassboro (Rowan University)[2]
# Could not process line: Hoboken (Stevens Institute of Technology)
# Could not process line: Madison (Drew University), (Fairleigh Dickinson University), (College of Saint Elizabeth)
# Could not process line: Newark (Rutgers University), (New Jersey Institute of Technology), (UMDNJ)
# Could not process line: New Brunswick (Rutgers University)[5]
# Could not process line: Princeton (Princeton University)[5]
# Could not process line: Union (Kean University)
# Could not process line: West Long Branch (Monmouth University)
# Could not process line: Hobbs (University of the Southwest)[2]
# Could not process line: Las Cruces (New Mexico State University)[2]
# Could not process line: Las Vegas (New Mexico Highlands University)[2]
# Could not process line: Portales (Eastern New Mexico University)[2]
# Could not process line: Silver City (Western New Mexico University)[2]
# Could not process line: Alfred (Alfred University, Alfred State College)[2]
# Could not process line: Albany (SUNY Albany, Siena College, Albany College of Pharmacy, Albany Law School, Albany Medical College, College of Saint Rose, Excelsior College, Maria College of Albany, Mildred Elley, Sage College of Albany)
# Could not process line: Aurora (Wells College)[21]
# Could not process line: Binghamton (Binghamton University)[2]
# Could not process line: Brockport (SUNY Brockport)[5]
# Could not process line: Buffalo (University at Buffalo)
# Could not process line: Canton (St. Lawrence University, SUNY Canton)[2]
# Could not process line: Clinton (Hamilton College)[2]
# Could not process line: Cobleskill (SUNY Cobleskill)[2]
# Could not process line: Delhi (SUNY Delhi)[2]
# Could not process line: Fredonia (SUNY Fredonia)[2]
# Could not process line: Geneseo (SUNY Geneseo)[2]
# Could not process line: Geneva (Hobart and William Smith Colleges)
# Could not process line: Hamilton (Colgate University)[2]
# Could not process line: Ithaca (Cornell University, Ithaca College)[1]
# Could not process line: Morningside Heights, Manhattan (Columbia University, Barnard College, Teachers College, Manhattan School of Music, Jewish Theological Seminary, Union Theological Seminary, Bank Street College of Education)
# Could not process line: New Paltz (SUNY New Paltz)[2]
# Could not process line: Oneonta (SUNY Oneonta, Hartwick College)[2]
# Could not process line: Oswego (SUNY Oswego)[2]
# Could not process line: Plattsburgh (SUNY Plattsburgh)[2]
# Could not process line: Potsdam (SUNY Potsdam, Clarkson University)[2]
# Could not process line: Poughkeepsie (Vassar College, Marist College)[2]
# Could not process line: Purchase (Purchase College, Manhattanville College)[2]
# Could not process line: Rochester (University of Rochester, Rochester Institute of Technology, Nazareth College, St. John Fisher College, Monroe Community College, Roberts Wesleyan College, SUNY Brockport, SUNY Empire State College)[2]
# Could not process line: Saratoga Springs (Skidmore College)[2]
# Could not process line: Seneca Falls (New York Chiropractic College)
# Could not process line: Stony Brook (Stony Brook University)
# Could not process line: Syracuse (Syracuse University, SUNY ESF, Upstate Medical University)
# Could not process line: Tivoli (Bard College)
# Could not process line: Troy (Rensselaer Polytechnic Institute, Russell Sage College, Hudson Valley Community College)
# Could not process line: West Point (United States Military Academy)
# Could not process line: Banner Elk (Lees-McRae College)
# Could not process line: Boiling Springs (Gardner-Webb University)[2]
# Could not process line: Boone (Appalachian State University)[2]
# Could not process line: Buies Creek (Campbell University)[2]
# Could not process line: Chapel Hill (University of North Carolina at Chapel Hill)[20]
# Could not process line: Cullowhee (Western Carolina University)[2]
# Could not process line: Davidson (Davidson College)[5]
# Could not process line: Durham (Duke University, North Carolina Central University)[5]
# Could not process line: Elon (Elon University)[2]
# Could not process line: Greensboro (University of North Carolina at Greensboro, Greensboro College, Guilford College, North Carolina A & T State University, Bennett College)
# Could not process line: Greenville (East Carolina University)[2]
# Could not process line: Hickory (Lenoir-Rhyne University)[2]
# Could not process line: Mars Hill (Mars Hill College)[2]
# Could not process line: Mount Olive (Mount Olive College)[2]
# Could not process line: Pembroke (University of North Carolina at Pembroke)[2]
# Could not process line: Wilmington, North Carolina (University of North Carolina at Wilmington)
# Could not process line: Wingate (Wingate University)[2]
# Could not process line: Winston-Salem (Wake Forest University, University of North Carolina School of the Arts, Salem College, Winston-Salem State University)
# Could not process line: Fargo (North Dakota State University)[18]
# Could not process line: Grand Forks (University of North Dakota)[5]
# Could not process line: Ada (Ohio Northern University)[2]
# Could not process line: Alliance (University of Mount Union)
# Could not process line: Ashland (Ashland University)[2]
# Could not process line: Athens (Ohio University)[2]
# Could not process line: Berea (Baldwin Wallace College)
# Could not process line: Bluffton (Bluffton University)[2]
# Could not process line: Bowling Green (Bowling Green State University)[2]
# Could not process line: Cedarville (Cedarville University)[2]
# Could not process line: Columbus (Ohio State University)
# Could not process line: Delaware (Ohio Wesleyan University)
# Could not process line: Fairborn (Wright State University)
# Could not process line: Findlay (University of Findlay)
# Could not process line: Gambier (Kenyon College)[2]
# Could not process line: Granville (Denison University)[2]
# Could not process line: Hiram (Hiram College)[2]
# Could not process line: Kent (Kent State University)[2]
# Could not process line: Nelsonville (Hocking College)[2]
# Could not process line: New Concord (Muskingum College)[2]
# Could not process line: Oberlin (Oberlin College)[5]
# Could not process line: Oxford (Miami University)[5]
# Could not process line: Rio Grande (University of Rio Grande)[2]
# Could not process line: Wilberforce (Wilberforce University, Central State University)[2]
# Could not process line: Ada (East Central University)[2]
# Could not process line: Alva (Northwestern Oklahoma State University)[2]
# Could not process line: Durant (Southeastern Oklahoma State University)[2]
# Could not process line: Edmond (University of Central Oklahoma, Oklahoma Christian University)[2]
# Could not process line: Goodwell (Oklahoma Panhandle State University)[2]
# Could not process line: Langston (Langston University)[5]
# Could not process line: Norman (University of Oklahoma)[1]
# Could not process line: Stillwater (Oklahoma State University)[5]
# Could not process line: Tahlequah (Northeastern State University)[2]
# Could not process line: Tulsa (The University of Tulsa)
# Could not process line: Weatherford (Southwestern Oklahoma State University)
# Could not process line: Ashland (Southern Oregon University)[2]
# Could not process line: Corvallis (Oregon State University)[20]
# Could not process line: Eugene (Lane Community College, Northwest Christian University, University of Oregon)[20]
# Could not process line: Forest Grove (Pacific University)
# Could not process line: Klamath Falls (Klamath Community College, Oregon Institute of Technology)
# Could not process line: La Grande (Eastern Oregon University)[2]
# Could not process line: Marylhurst (Marylhurst University)
# Could not process line: McMinnville (Linfield College)
# Could not process line: Monmouth (Western Oregon University)[2]
# Could not process line: Newberg (George Fox University)
# Could not process line: Altoona (Penn State Altoona)
# Could not process line: Annville (Lebanon Valley College)[2]
# Could not process line: Bethlehem (Lehigh University, Moravian College)
# Could not process line: Bloomsburg (Bloomsburg University of Pennsylvania)[2]
# Could not process line: Bradford (University of Pittsburgh at Bradford)
# Could not process line: California (California University of Pennsylvania)[2]
# Could not process line: Carlisle (Dickinson College)
# Could not process line: Cecil B. Moore, Philadelphia, also known as "Templetown" (Temple University)
# Could not process line: Clarion (Clarion University of Pennsylvania)[2]
# Could not process line: Collegeville (Ursinus College)
# Could not process line: Cresson (Mount Aloysius College)[2]
# Could not process line: East Stroudsburg (East Stroudsburg University of Pennsylvania)[2]
# Could not process line: Edinboro (Edinboro University of Pennsylvania)[2]
# Could not process line: Erie (Gannon University, Mercyhurst College, Penn State Erie)
# Could not process line: Gettysburg (Gettysburg College)[2]
# Could not process line: Greensburg (Seton Hill University, University of Pittsburgh at Greensburg)
# Could not process line: Grove City (Grove City College)[2]
# Could not process line: Huntingdon (Juniata College)[2]
# Could not process line: Indiana (Indiana University of Pennsylvania)[2]
# Could not process line: Johnstown (University of Pittsburgh at Johnstown)
# Could not process line: Kutztown (Kutztown University of Pennsylvania)[2]
# Could not process line: Lancaster (Franklin & Marshall)
# Could not process line: Lewisburg (Bucknell University)[5]
# Could not process line: Lock Haven (Lock Haven University of Pennsylvania)[2]
# Could not process line: Loretto (St. Francis University)[2]
# Could not process line: Mansfield (Mansfield University of Pennsylvania)[2]
# Could not process line: Meadville (Allegheny College)
# Could not process line: Mont Alto (Penn State Mont Alto)
# Could not process line: Millersville (Millersville University of Pennsylvania)[2]
# Could not process line: New Wilmington (Westminster College)[2]
# Could not process line: North East (Mercyhurst North East)
# Could not process line: University City, Philadelphia (Drexel University, University of Pennsylvania, University of the Sciences in Philadelphia)
# Could not process line: Oakland, Pittsburgh (Carnegie Mellon University, University of Pittsburgh, Carlow University)
# Could not process line: Reading (Albright College, Alvernia University, Penn State Berks)
# Could not process line: Selinsgrove (Susquehanna University)[2]
# Could not process line: Shippensburg (Shippensburg University of Pennsylvania)[2]
# Could not process line: Slippery Rock (Slippery Rock University of Pennsylvania)[2]
# Could not process line: State College (Pennsylvania State University)[22]
# Could not process line: Villanova (Villanova University)
# Could not process line: Waynesburg (Waynesburg University)
# Could not process line: West Chester (West Chester University of Pennsylvania)
# Could not process line: Wilkes-Barre (King's College, Wilkes University)
# Could not process line: Williamsport (Lycoming College, Pennsylvania College of Technology)[2]
# Could not process line: Kingston (University of Rhode Island)[2]
# Could not process line: Providence (Brown University, (University of Rhode Island), Rhode Island School of Design, Johnson and Wales University, Providence College, Community College of Rhode Island, Rhode Island College, and Roger Williams University.)
# Could not process line: Central (Southern Wesleyan University)[2]
# Could not process line: Charleston (College of Charleston, The Citadel, MUSC)
# Could not process line: Clemson (Clemson University)[2]
# Could not process line: Clinton (Presbyterian College)
# Could not process line: Columbia (University of South Carolina)[14]
# Could not process line: Due West (Erskine College)
# Could not process line: Florence (Francis Marion University)
# Could not process line: Greenwood (Lander University)
# Could not process line: Orangeburg (South Carolina State University, Claflin University)[2]
# Could not process line: Rock Hill (Winthrop University)
# Could not process line: Spartanburg (Wofford College, Converse College, University of South Carolina Upstate, Spartanburg Methodist College, Edward Via College of Osteopathic Medicine, Spartanburg Community College, Virginia College, Sherman College of Chiropractic)
# Could not process line: Brookings (South Dakota State University)[2]
# Could not process line: Madison (Dakota State University)
# Could not process line: Spearfish (Black Hills State University)
# Could not process line: Vermillion (University of South Dakota)[5]
# Could not process line: Chattanooga (University of Tennessee at Chattanooga)
# Could not process line: Collegedale (Southern Adventist University)
# Could not process line: Cookeville (Tennessee Technological University)[2]
# Could not process line: Harrogate (Lincoln Memorial University)[2]
# Could not process line: Henderson (Freed-Hardeman University)[2]
# Could not process line: Johnson City (East Tennessee State University)
# Could not process line: Knoxville (University of Tennessee)
# Could not process line: Martin (University of Tennessee at Martin)[2]
# Could not process line: McKenzie (Bethel University)[2]
# Could not process line: Memphis (Christian Brothers University, LeMoyne-Owen College, Memphis College of Art, Memphis Theological Seminary, Rhodes College, Southern College of Optometry, Southwest Tennessee Community College, University of Memphis, University of Tennessee Health Science Center, Visible Music College)
# Could not process line: Murfreesboro (Middle Tennessee State University)[2]
# Could not process line: Nashville (Vanderbilt University, Belmont University, Tennessee State University, Lipscomb University, Fisk University, Aquinas College, Trevecca Nazarene University)
# Could not process line: Sewanee (Sewanee: the University of the South)[2]
# Could not process line: Abilene (Abilene Christian University, Hardin-Simmons University, McMurry University)
# Could not process line: Alpine (Sul Ross State University)[2]
# Could not process line: Austin (University of Texas at Austin, St. Edwards University, Huston-Tillotson University)[2]
# Could not process line: Beaumont (Lamar University)
# Could not process line: Canyon (West Texas A&M University)[2]
# Could not process line: College Station (Texas A&M University)[5]
# Could not process line: Commerce (Texas A&M University–Commerce)[2]
# Could not process line: Dallas (Southern Methodist University)
# Could not process line: Denton (University of North Texas, Texas Woman's University)[2]
# Could not process line: Fort Worth (Texas Christian University, Texas Wesleyan University)
# Could not process line: Georgetown (Southwestern University)
# Could not process line: Huntsville (Sam Houston State University)[2]
# Could not process line: Houston (University of Houston, Texas Southern University, Rice University, Houston Baptist University)
# Could not process line: Keene (Southwestern Adventist University)[2]
# Could not process line: Kingsville (Texas A&M University–Kingsville)[2]
# Could not process line: Lubbock (Texas Tech University, Lubbock Christian University)
# Could not process line: Nacogdoches (Stephen F. Austin State University)[2]
# Could not process line: Plainview (Wayland Baptist University)[2]
# Could not process line: Prairie View (Prairie View A&M University)[2]
# Could not process line: San Marcos (Texas State University)[5]
# Could not process line: Stephenville (Tarleton State University)[2]
# Could not process line: Waco (Baylor University)
# Could not process line: Cedar City (Southern Utah University)[2]
# Could not process line: Logan (Utah State University)[2]
# Could not process line: Provo (Brigham Young University)[5]
# Could not process line: Orem (Utah Valley University)
# Could not process line: Salt Lake City (University of Utah)
# Could not process line: Ephraim (Snow College)
# Could not process line: Burlington (University of Vermont, Champlain College and Saint Michael's College)[2]
# Could not process line: Castleton (Castleton State College)[2]
# Could not process line: Johnson (Johnson State College)[2]
# Could not process line: Lyndonville (Lyndon State College)[2]
# Could not process line: Middlebury (Middlebury College)[2]
# Could not process line: Northfield (Norwich University)[2]
# Could not process line: Blacksburg (Virginia Polytechnic Institute and State University)[5]
# Could not process line: Bridgewater (Bridgewater College)[2]
# Could not process line: Charlottesville (University of Virginia)[23]
# Could not process line: Farmville (Longwood University, Hampden-Sydney College)[2]
# Could not process line: Fredericksburg (University of Mary Washington)[2]
# Could not process line: Harrisonburg (James Madison University, Eastern Mennonite University)[2]
# Could not process line: Lexington (Washington and Lee University, Virginia Military Institute)[2]
# Could not process line: Lynchburg (Lynchburg College, Randolph College, Liberty University, Central Virginia Community College)
# Could not process line: Radford (Radford University)[2]
# Could not process line: Williamsburg (The College of William & Mary)[2]
# Could not process line: Wise (University of Virginia's College at Wise)[2]
# Could not process line: Chesapeake (Averett University, DeVry University, Troy University, Tidewater Community College, Strayer University, Everest University, Sentera College of Health Sciences, St Leo University)[2]
# Could not process line: Bellingham (Western Washington University)
# Could not process line: Cheney (Eastern Washington University)[2]
# Could not process line: Ellensburg (Central Washington University)[5]
# Could not process line: Pullman (Washington State University)[5]
# Could not process line: University District, Seattle (University of Washington)[5]
# Could not process line: Athens (Concord University)[2]
# Could not process line: Buckhannon (West Virginia Wesleyan College)[2]
# Could not process line: Fairmont (Fairmont State University)[2]
# Could not process line: Glenville (Glenville State College)[2]
# Could not process line: Huntington (Marshall University)[2]
# Could not process line: Montgomery (West Virginia University Institute of Technology)[2]
# Could not process line: Morgantown (West Virginia University)[2]
# Could not process line: Shepherdstown (Shepherd University)[2]
# Could not process line: West Liberty (West Liberty University)[2]
# Could not process line: Appleton (Lawrence University)
# Could not process line: Eau Claire (University of Wisconsin–Eau Claire)
# Could not process line: Green Bay (University of Wisconsin-Green Bay)
# Could not process line: La Crosse (University of Wisconsin–La Crosse, Western Technical College, Viterbo University)[2]
# Could not process line: Madison (University of Wisconsin–Madison)[2]
# Could not process line: Menomonie (University of Wisconsin–Stout)[2]
# Could not process line: Milwaukee (Marquette University, University of Wisconsin–Milwaukee)
# Could not process line: Oshkosh (University of Wisconsin–Oshkosh)
# Could not process line: Platteville (University of Wisconsin–Platteville)[2]
# Could not process line: River Falls (University of Wisconsin–River Falls)[2]
# Could not process line: Stevens Point (University of Wisconsin–Stevens Point)[2]
# Could not process line: Waukesha (Carroll University)
# Could not process line: Whitewater (University of Wisconsin–Whitewater)[2]
# Could not process line: Laramie (University of Wyoming)[5]
# Could not process line: +000 (555)
# **********************************************************
# Legtöbb egyetem: Alabama (1 db)
# Legkevesebb egyetem: Alabama (1 db)
# **********************************************************

# %% [markdown]
# 2. Bővítsük ki az adatbázisunkat egy oszloppal, mely tartalmazza az államok rövidítését is (pl. Texas - TX, California - CA stb.).  [Forrás](https://en.wikipedia.org/wiki/List_of_U.S._state_abbreviations).

# %%
abbreviations = {}

with open('/content/sample_data/data.csv') as f:
    for line in f:
        state, abbreviation = line.strip().split(',')
        abbreviations[state] = abbreviation

def load_universities(filename):
    universities = {}
    with open(filename) as f:
        state = None
        for line in f:
            line = line.strip()
            if not line:
                continue
            if "[edit]" in line:
                state = line.replace("[edit]", "").strip()
                if state in abbreviations:
                    state_abbrev = abbreviations[state]
                else:
                    state_abbrev = None
                universities[state] = {"abbrev": state_abbrev, "universities": []}
            else:
                universities[state]["universities"].append(line)
    return universities

load_universities('/content/sample_data/egyetemek.txt')

# %% [markdown]
# 3. Az adatbázist integráljuk a [List of states and territories of the United States by population](https://en.wikipedia.org/wiki/List_of_states_and_territories_of_the_United_States_by_population) linken szereplő népszámlálási adatokkal és számoljuk ki államonként hány főre jut egy egyetemi város.

# %% [markdown]
# 4. Hasonlóan, a [List of U.S. states and territories by area](https://en.wikipedia.org/wiki/List_of_U.S._states_and_territories_by_area) linken szereplő területi adatok integrálásával, számoljuk ki államonként átlagban hány négyzetkilométerre jut egy egyetemi város.

# %% [markdown]
# 5. A [példa](https://datasciencechalktalk.com/2019/09/28/analyzing-u-s-exports-with-plotly/), a kivitelt, exportmennyiséget ábrázolja az Amerikai Egyesült Államok térképen, államonként lebontva ezt. Készítsünk hasonló ábrákat az egyetemek abszolút, lakoság és terület szerinti eloszlásáról is. Az ábrákat exportáljuk kép formájában.
# ![](https://i.ibb.co/s1zdnLY/mapplot.png)
#
# Ábra 1. [Térképen való ábrázolás](https://plotly.com/python/maps/) Plotly segítségével. [Forrás](https://datasciencechalktalk.com/2019/09/28/analyzing-u-s-exports-with-plotly/).

# %% [markdown]
# 6. Számoljuk ki, hány egyetem van városonként, majd összesítve államonként. Ehhez az `egyetemek.txt` fájlban miután megkapunk egy várost, az utána következő kerek zárójelek között megszámoljuk, hány vesszővel elválasztott karakterlánc található.
# Pl. a következő sorban:	`Claremont (Claremont McKenna College, Pomona College, Harvey Mudd College, Scripps College, Pitzer College, Keck Graduate Institute, Claremont Graduate University)[5]` -> 6 vessző van a kerek zárójelek között, tehát 7 egyetem van a városban.
# Melyik államban és melyik városban van a legtöbb egyetem?
